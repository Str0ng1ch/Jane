# %%
import sys
sys.path.append("/Users/egorkolesnikv/Documents/ai_talent/Jane")

# %%
from src.data import (
    ChunkConfig, process_book, parse_and_save
)

# %%
config = ChunkConfig()

# %%
pdf_name = "С_справочник_ГУД_качкин_юридический_2024"
subfolder = "andragogy"
pdf_path = f"../../data/books/{subfolder}/{pdf_name}.pdf"
toc_path = f"../../data/toc/{pdf_name}_toc.json"
cache_path = f"../../data/cache/{pdf_name}_parsed.json"

# %%
parsed_pages = parse_and_save(pdf_path, cache_path)
# Out:
# Parsing PDF: ../../data/books/andragogy/С_справочник_ГУД_качкин_юридический_2024.pdf
# Started parsing the file under job_id c624929d-41fa-4a57-8f21-b24af74773ae
# .Parsed 466 pages
# Saved 466 parsed pages to ../../data/cache/С_справочник_ГУД_качкин_юридический_2024_parsed.json

# %%
print(parsed_pages[25].content)
# Out:
# # Chapter Title: Urban Planning and Land Use Regulations
#
# ## Introduction
#
# Urban planning is a critical aspect of urban studies, focusing on the development and organization of land use in urban areas. This chapter discusses the legal frameworks and requirements that govern urban planning, particularly in relation to land use and development projects.
#
# ## Legal Foundations for Urban Planning
#
# 1. **Project Documentation**: As of January 1, 2016, certain documents serve as the basis for developing project documentation concerning linear objects.
#
# 2. **Land Expropriation**: Alongside territorial planning documents, these regulations provide grounds for decisions regarding the expropriation of land parcels.
#
# 3. **Construction Parameters**: The regulations define construction parameters when a project is implemented under a development agreement for built-up areas or a comprehensive land development agreement.
#
# 4. **Land Ownership Restrictions**: If a planning project involves the placement of a facility of federal, regional, or local significance on a land parcel, that parcel cannot be granted for ownership or lease.
#
# 5. **Capital Construction Requirements**: As of September 1, 2018, it is mandatory to comply with these regulations when placing capital construction objects that are not linear and are necessary for their functioning within specially protected natural areas or forest land.
#
# 6. **Comprehensive Development**: As of December 30, 2020, these regulations are obligatory if comprehensive land development is planned.
#
# 7. **Individual Housing Construction**: From March 1, 2022, it is mandatory for projects involving individual housing construction that attract funds from participants in shared construction, in accordance with Federal Law No. 214-FZ dated December 30, 2004, regarding participation in shared construction of apartment buildings and other real estate.
#
# ## Traffic Organization Projects
#
# Since December 30, 2018, the project for land planning may include a traffic organization project developed in accordance with the requirements of Federal Law No. 443-FZ dated December 29, 2017, concerning traffic organization in the Russian Federation.
#
# ## Land Division Projects
#
# Land division projects are typically developed simultaneously with land planning projects. The primary goal of this document is to determine the location of boundaries for newly created and modified land parcels, establish, change, or cancel red lines for built-up areas where new capital construction objects are not planned, and address the formation or modification of land parcels within territories where comprehensive development is not anticipated, provided that such establishment, change, or cancellation solely results in altering the boundaries of public use areas.
#
# ### Structure of Land Division Projects
#
# The land division project consists of a main part that requires approval and materials justifying this project.
#
# #### Main Part of the Land Division Project
#
# The main part includes a textual section and land division drawings, which display the following information:
#
# 1. Boundaries of planned and existing elements of the planning structure.
# 2. Red lines.
# 3. Setback lines from red lines to determine permissible locations for buildings, structures, and facilities.
# 4. Boundaries of newly created and/or modified land parcels, including conditional numbers for parcels that may be reserved or expropriated for state or municipal needs.
# 5. Boundaries of public servitudes.
#
# #### Textual Section of the Land Division Project
#
# The textual section includes:
#
# 1. A list and details about the area of newly created land parcels, including possible methods of their formation.
